# %%
link="https://www.googleapis.com/books/v1/volumes"
api="AIzaSyCLFndPwb0LWBJmBMb38p46-MMq7FlCXrE"

# %%
import requests
import pandas as pd

# Define API URL and API Key
link = "https://www.googleapis.com/books/v1/volumes"
api = "AIzaSyCLFndPwb0LWBJmBMb38p46-MMq7FlCXrE"

# Function to fetch books data with pagination
def fetch_books_data(query, max_results=40, total_results=200):
    """
    Fetch books data using Google Books API with pagination.

    Args:
        query (str): Search keyword for the books.
        max_results (int): Number of results per page (API limit is 40).
        total_results (int): Total number of results to fetch.

    Returns:
        pd.DataFrame: DataFrame containing the fetched books data.
    """
    all_books = []
    start_index = 0

    while start_index < total_results:
        print(f"Fetching results from {start_index} to {start_index + max_results}...")

        # Prepare parameters for the API call
        params = {
            "q": query,
            "startIndex": start_index,
            "maxResults": max_results,
            "key": api
        }

        # Make the API call
        response = requests.get(link, params=params)
        if response.status_code != 200:
            print(f"Error: Unable to fetch data. HTTP Status Code: {response.status_code}")
            break

        # Parse the JSON response
        data = response.json()
        books = data.get("items", [])
        for book in books:
            volume_info = book.get("volumeInfo", {})
            sale_info = book.get("saleInfo", {})

            # Extract required fields
            all_books.append({
                "book_id": book.get("id", None),
                "search_key": query,  # Store the search term for reference
                "book_title": volume_info.get("title", None),
                "book_subtitle": volume_info.get("subtitle", "NA"),
                "book_authors": ", ".join(volume_info.get("authors", [])),
                "book_description": volume_info.get("description", "NA"),
                "industryIdentifiers": ", ".join([identifier['identifier'] for identifier in volume_info.get('industryIdentifiers', [])]),
                "text_readingModes": volume_info.get("readingModes", {}).get("text", False),
                "image_readingModes": volume_info.get("readingModes", {}).get("image", False),
                "pageCount": volume_info.get("pageCount", None),
                "categories": ", ".join(volume_info.get("categories", [])),
                "language": volume_info.get("language", None),
                "imageLinks": volume_info.get("imageLinks", {}).get("thumbnail", None),
                "ratingsCount": volume_info.get("ratingsCount", None),
                "averageRating": volume_info.get("averageRating", None),
                "country": sale_info.get("country", None),
                "saleability": sale_info.get("saleability", None),
                "isEbook": sale_info.get("isEbook", False),
                "amount_listPrice": sale_info.get("listPrice", {}).get("amount", None),
                "currencyCode_listPrice": sale_info.get("listPrice", {}).get("currencyCode", None),
                "amount_retailPrice": sale_info.get("retailPrice", {}).get("amount", None),
                "currencyCode_retailPrice": sale_info.get("retailPrice", {}).get("currencyCode", None),
                "buyLink": sale_info.get("buyLink", None),
                "year": volume_info.get("publishedDate", "").split("-")[0]  # Extract year from publishedDate
            })


        # Increment the start index for the next page
        start_index += max_results

    # Return the collected data as a DataFrame
    return pd.DataFrame(all_books)

# Fetch data for a specific keyword (e.g., "data science")
books_df1 = fetch_books_data(query="data science", total_results=500)  # Fetch up to 200 results
books_df1

# Fetch data for a specific keyword (e.g., "data science")
books_df2 = fetch_books_data(query="Python", total_results=400)  # Fetch up to 200 results
books_df2

# Fetch data for a specific keyword (e.g., "data science")
books_df3 = fetch_books_data(query="Java", total_results=400)  # Fetch up to 200 results
books_df3

# Fetch data for a specific keyword (e.g., "data science")
books_df4 = fetch_books_data(query="SQL", total_results=400)  # Fetch up to 200 results
books_df4

# Fetch data for a specific keyword (e.g., "data science")
books_df5 = fetch_books_data(query="HTML", total_results=400)  # Fetch up to 200 results
books_df5

# Fetch data for a specific keyword (e.g., "data science")
books_df6 = fetch_books_data(query="Harry Potter", total_results=400)  # Fetch up to 200 results
books_df6

# Fetch data for a specific keyword (e.g., "data science")
books_df7 = fetch_books_data(query="Ponniyin Selvan", total_results=400)  # Fetch up to 200 results
books_df7

#Fetch data for a specific keyword (e.g., "data science")
books_df8 = fetch_books_data(query="Mathematics", total_results=400)  # Fetch up to 200 results
books_df8


#Fetch data for a specific keyword (e.g., "data science")
books_df9 = fetch_books_data(query="Javascript", total_results=400)  # Fetch up to 200 results
books_df9

#Fetch data for a specific keyword (e.g., "data science")
books_df10 = fetch_books_data(query="Discrete mathematics", total_results=400)  # Fetch up to 00 results
books_df10

#Fetch data for a specific keyword (e.g., "data science")
books_df11 = fetch_books_data(query="Fundamentals of fluid mechanics", total_results=400)  # Fetch up to 200 results
books_df11

#Fetch data for a specific keyword (e.g., "data science")
books_df12 = fetch_books_data(query="Probability and statistics ", total_results=400)  # Fetch up to 200 results
books_df12

#Fetch data for a specific keyword (e.g., "data science")
books_df13 = fetch_books_data(query="Engineering books", total_results=200)  # Fetch up to 200 results
books_df13

#Fetch data for a specific keyword (e.g., "data science")
books_df14 = fetch_books_data(query="English poem", total_results=200)  # Fetch up to 200 results
books_df14


#Fetch data for a specific keyword (e.g., "data science")
books_df15 = fetch_books_data(query="Physics books", total_results=200)  # Fetch up to 200 results
books_df15

#Fetch data for a specific keyword (e.g., "data science")
books_df16 = fetch_books_data(query="Chemistry books ", total_results=200)  # Fetch up to 200 results
books_df16

#Fetch data for a specific keyword (e.g., "data science")
books_df17 = fetch_books_data(query="Business books ", total_results=200)  # Fetch up to 200 results
books_df17

#Fetch data for a specific keyword (e.g., "data science")
books_df18 = fetch_books_data(query="Novels books ", total_results=200)  # Fetch up to 200 results
books_df18

#Fetch data for a specific keyword (e.g., "data science")
books_df19 = fetch_books_data(query="Social science books ", total_results=200)  # Fetch up to 200 results
books_df19

#Fetch data for a specific keyword (e.g., "data science")
books_df20 = fetch_books_data(query="History books ", total_results=200)  # Fetch up to 200 results
books_df20

final_df = pd.concat([books_df1, books_df2, books_df3,books_df4,books_df5,books_df6,books_df7,books_df8,books_df9,books_df10,books_df11,books_df12,books_df13,books_df14,books_df15,books_df16,books_df17,books_df18,books_df19,books_df20], ignore_index=True)
final_df
# Out:
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 200 to 240...
# Fetching results from 240 to 280...
# Fetching results from 280 to 320...
# Fetching results from 320 to 360...
# Fetching results from 360 to 400...
# Fetching results from 400 to 440...
# Fetching results from 440 to 480...
# Fetching results from 480 to 520...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 200 to 240...
# Fetching results from 240 to 280...
# Fetching results from 280 to 320...
# Fetching results from 320 to 360...
# Fetching results from 360 to 400...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# ...

# %%
final_df.isnull().sum()
# Out:
# book_id                        0
# search_key                     0
# book_title                     1
# book_subtitle                  0
# book_authors                   0
# book_description               0
# industryIdentifiers            0
# text_readingModes              0
# image_readingModes             0
# pageCount                    152
# categories                     0
# language                       0
# imageLinks                   444
# ratingsCount                5269
# averageRating               5269
# country                        0
# saleability                    0
# isEbook                        0
# amount_listPrice            4418
# currencyCode_listPrice      4418
# amount_retailPrice          4418
# currencyCode_retailPrice    4418
# buyLink                     4217
# year                           0
# dtype: int64

# %%
final_df.dropna(inplace=True)
final_df
# Out:
#            book_id      search_key  \
# 6     RKvoDwAAQBAJ    data science
# 12    vcVKAQAAQBAJ    data science
# 13    axruBQAAQBAJ    data science
# 17    yPOUDwAAQBAJ    data science
# 31    XhKSDwAAQBAJ    data science
# ...            ...             ...
# 6417  Ipwpbhd6sQUC  History books
# 6422  fcy1N5GXs4wC  History books
# 6444  v2ZSDwAAQBAJ  History books
# 6450  u8w_DwAAQBAJ  History books
# 6491  xGJODwAAQBAJ  History books
#
#                                              book_title  \
# 6     Data Science Fundamentals and Practical Approa...
# 12                                   Doing Data Science
# 13                  Data Science and Big Data Analytics
# 17    Business Data Science: Combining Machine Learn...
# 31                            Data Science from Scratch
# ...                                                 ...
# 6417                           India Since Independence
# 6422                                   China: A History
# ...

# %%
import requests
import pandas as pd

# Define API URL and API Key
link = "https://www.googleapis.com/books/v1/volumes"
api = "AIzaSyCLFndPwb0LWBJmBMb38p46-MMq7FlCXrE"

# Function to fetch books data with pagination
def fetch_books_data(query, max_results=40, total_results=200):
    """
    Fetch books data using Google Books API with pagination.

    Args:
        query (str): Search keyword for the books.
        max_results (int): Number of results per page (API limit is 40).
        total_results (int): Total number of results to fetch.

    Returns:
        pd.DataFrame: DataFrame containing the fetched books data.
    """
    all_books = []
    start_index = 0

    while start_index < total_results:
        print(f"Fetching results from {start_index} to {start_index + max_results}...")

        # Prepare parameters for the API call
        params = {
            "q": query,
            "startIndex": start_index,
            "maxResults": max_results,
            "key": api
        }

        # Make the API call
        response = requests.get(link, params=params)
        if response.status_code != 200:
            print(f"Error: Unable to fetch data. HTTP Status Code: {response.status_code}")
            break

        # Parse the JSON response
        data = response.json()
        books = data.get("items", [])
        for book in books:
            volume_info = book.get("volumeInfo", {})
            sale_info = book.get("saleInfo", {})

            # Extract required fields
            all_books.append({
                "book_id": book.get("id", None),
                "search_key": query,  # Store the search term for reference
                "book_title": volume_info.get("title", None),
                "book_subtitle": volume_info.get("subtitle", "NA"),
                "book_authors": ", ".join(volume_info.get("authors", [])),
                "book_description": volume_info.get("description", "NA"),
                "industryIdentifiers": ", ".join([identifier['identifier'] for identifier in volume_info.get('industryIdentifiers', [])]),
                "text_readingModes": volume_info.get("readingModes", {}).get("text", False),
                "image_readingModes": volume_info.get("readingModes", {}).get("image", False),
                "pageCount": volume_info.get("pageCount", None),
                "categories": ", ".join(volume_info.get("categories", [])),
                "language": volume_info.get("language", None),
                "imageLinks": volume_info.get("imageLinks", {}).get("thumbnail", None),
                "ratingsCount": volume_info.get("ratingsCount", None),
                "averageRating": volume_info.get("averageRating", None),
                "country": sale_info.get("country", None),
                "saleability": sale_info.get("saleability", None),
                "isEbook": sale_info.get("isEbook", False),
                "amount_listPrice": sale_info.get("listPrice", {}).get("amount", None),
                "currencyCode_listPrice": sale_info.get("listPrice", {}).get("currencyCode", None),
                "amount_retailPrice": sale_info.get("retailPrice", {}).get("amount", None),
                "currencyCode_retailPrice": sale_info.get("retailPrice", {}).get("currencyCode", None),
                "buyLink": sale_info.get("buyLink", None),
                "year": volume_info.get("publishedDate", "").split("-")[0]  # Extract year from publishedDate
            })


        # Increment the start index for the next page
        start_index += max_results

    # Return the collected data as a DataFrame
    return pd.DataFrame(all_books)

#Fetch data for a specific keyword (e.g., "data science")
books_df41 = fetch_books_data(query="Business Law books  ", total_results=200)  # Fetch up to 200 results
books_df41
#Fetch data for a specific keyword (e.g., "data science")
books_df42 = fetch_books_data(query="Commercial Law books ", total_results=200)  # Fetch up to 200 results
books_df42
#Fetch data for a specific keyword (e.g., "data science")
books_df43 = fetch_books_data(query="Bussiness Management  books ", total_results=200)  # Fetch up to 200 results
books_df43
#Fetch data for a specific keyword (e.g., "data science")
books_df44 = fetch_books_data(query="Corporate Accounting books ", total_results=200)  # Fetch up to 200 results
books_df44
#Fetch data for a specific keyword (e.g., "data science")
books_df45 = fetch_books_data(query="Money Management books ", total_results=200)  # Fetch up to 200 results
books_df45
#Fetch data for a specific keyword (e.g., "data science"),
books_df46 = fetch_books_data(query="Material Management books ", total_results=200)  # Fetch up to 200 results
books_df46
#Fetch data for a specific keyword (e.g., "data science")
books_df47 = fetch_books_data(query="Data Structure books ", total_results=200)  # Fetch up to 200 results
books_df47
#Fetch data for a specific keyword (e.g., "data science")
books_df48 = fetch_books_data(query="E-Business books ", total_results=100)  # Fetch up to 200 results
books_df48
#Fetch data for a specific keyword (e.g., "data science")
books_df49 = fetch_books_data(query="Supply Chain Management  books ", total_results=100)  # Fetch up to 200 results
books_df49
#Fetch data for a specific keyword (e.g., "data science")
books_df50 = fetch_books_data(query="Law books ", total_results=100)  # Fetch up to 200 results
books_df50
#Fetch data for a specific keyword (e.g., "data science")
books_df51 = fetch_books_data(query="Domestic and Internation Logistics Management", total_results=100)  # Fetch up to 200 results
books_df51

#Fetch data for a specific keyword (e.g., "data science")
books_df52= fetch_books_data(query="Abstract Algebra books ", total_results=200)  # Fetch up to 200 results
books_df52
#Fetch data for a specific keyword (e.g., "data science")
books_df53 = fetch_books_data(query="Trigonometry books ", total_results=200)  # Fetch up to 200 results
books_df53
#Fetch data for a specific keyword (e.g., "data science")
books_df54 = fetch_books_data(query="Geometry books ", total_results=400)  # Fetch up to 200 results
books_df54
#Fetch data for a specific keyword (e.g., "data science")
books_df55 = fetch_books_data(query="Digital Signal Processing books ", total_results=400)  # Fetch up to 200 results
books_df55
#Fetch data for a specific keyword (e.g., "data science")
books_df56 = fetch_books_data(query="Software Testing books ", total_results=400)  # Fetch up to 200 results
books_df56
#Fetch data for a specific keyword (e.g., "data science")
books_df57 = fetch_books_data(query="Mechanical Engineering books ", total_results=400)  # Fetch up to 200 results
books_df57
#Fetch data for a specific keyword (e.g., "data science")
books_df58 = fetch_books_data(query="Computer Networks books ", total_results=100)  # Fetch up to 200 results
books_df58
#Fetch data for a specific keyword (e.g., "data science")
books_df59 = fetch_books_data(query="Cloud Computing books ", total_results=100)  # Fetch up to 200 results
books_df59

#Fetch data for a specific keyword (e.g., "data science")
books_df60 = fetch_books_data(query="Artificial Intelligence books ", total_results=200)  # Fetch up to 200 results
books_df60

fin1_df = pd.concat([books_df41,books_df42,books_df43,books_df44,books_df45,books_df46,books_df47,books_df48,books_df49,books_df50,books_df51,books_df52,books_df53,books_df54,books_df55,books_df56,books_df57,books_df58,books_df59,books_df60], ignore_index=True)
fin1_df
# Out:
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# ...

# %%
fin1_df.isnull().sum()
# Out:
# book_id                        0
# search_key                     0
# book_title                     0
# book_subtitle                  0
# book_authors                   0
# book_description               0
# industryIdentifiers            0
# text_readingModes              0
# image_readingModes             0
# pageCount                    182
# categories                     0
# language                       0
# imageLinks                   574
# ratingsCount                3618
# averageRating               3618
# country                        0
# saleability                    0
# isEbook                        0
# amount_listPrice            3013
# currencyCode_listPrice      3013
# amount_retailPrice          3013
# currencyCode_retailPrice    3013
# buyLink                     2882
# year                           0
# dtype: int64

# %%
fin1_df.dropna(inplace=True)
fin1_df
# Out:
#            book_id                      search_key  \
# 7     nkxX2jCV08kC            Business Law books
# 43    hGCXDQAAQBAJ            Business Law books
# 50    3-WfBwAAQBAJ            Business Law books
# 76    2EJDDAAAQBAJ            Business Law books
# 93    93jQWFsOlT0C            Business Law books
# ...            ...                             ...
# 4299  pjRkCQAAQBAJ  Artificial Intelligence books
# 4303  fEsZ3Ey-Hq4C  Artificial Intelligence books
# 4312  XuJoDQAAQBAJ  Artificial Intelligence books
# 4316  vbQlDQAAQBAJ  Artificial Intelligence books
# 4318  PMHiBAAAQBAJ  Artificial Intelligence books
#
#                                              book_title  \
# 7                                          Business Law
# 43                          Business Leadership and Law
# 50    Business Law and Ethics: Concepts, Methodologi...
# 76                          Mercantile Law, 8th Edition
# 93                            Legal Aspects of Business
# ...

# %%
import requests
import pandas as pd

# Define API URL and API Key
link = "https://www.googleapis.com/books/v1/volumes"
api = "AIzaSyCLFndPwb0LWBJmBMb38p46-MMq7FlCXrE"

# Function to fetch books data with pagination
def fetch_books_data(query, max_results=40, total_results=200):
    """
    Fetch books data using Google Books API with pagination.

    Args:
        query (str): Search keyword for the books.
        max_results (int): Number of results per page (API limit is 40).
        total_results (int): Total number of results to fetch.

    Returns:
        pd.DataFrame: DataFrame containing the fetched books data.
    """
    all_books = []
    start_index = 0

    while start_index < total_results:
        print(f"Fetching results from {start_index} to {start_index + max_results}...")

        # Prepare parameters for the API call
        params = {
            "q": query,
            "startIndex": start_index,
            "maxResults": max_results,
            "key": api
        }

        # Make the API call
        response = requests.get(link, params=params)
        if response.status_code != 200:
            print(f"Error: Unable to fetch data. HTTP Status Code: {response.status_code}")
            break

        # Parse the JSON response
        data = response.json()
        books = data.get("items", [])
        for book in books:
            volume_info = book.get("volumeInfo", {})
            sale_info = book.get("saleInfo", {})

            # Extract required fields
            all_books.append({
                "book_id": book.get("id", None),
                "search_key": query,  # Store the search term for reference
                "book_title": volume_info.get("title", None),
                "book_subtitle": volume_info.get("subtitle", "NA"),
                "book_authors": ", ".join(volume_info.get("authors", [])),
                "book_description": volume_info.get("description", "NA"),
                "industryIdentifiers": ", ".join([identifier['identifier'] for identifier in volume_info.get('industryIdentifiers', [])]),
                "text_readingModes": volume_info.get("readingModes", {}).get("text", False),
                "image_readingModes": volume_info.get("readingModes", {}).get("image", False),
                "pageCount": volume_info.get("pageCount", None),
                "categories": ", ".join(volume_info.get("categories", [])),
                "language": volume_info.get("language", None),
                "imageLinks": volume_info.get("imageLinks", {}).get("thumbnail", None),
                "ratingsCount": volume_info.get("ratingsCount", None),
                "averageRating": volume_info.get("averageRating", None),
                "country": sale_info.get("country", None),
                "saleability": sale_info.get("saleability", None),
                "isEbook": sale_info.get("isEbook", False),
                "amount_listPrice": sale_info.get("listPrice", {}).get("amount", None),
                "currencyCode_listPrice": sale_info.get("listPrice", {}).get("currencyCode", None),
                "amount_retailPrice": sale_info.get("retailPrice", {}).get("amount", None),
                "currencyCode_retailPrice": sale_info.get("retailPrice", {}).get("currencyCode", None),
                "buyLink": sale_info.get("buyLink", None),
                "year": volume_info.get("publishedDate", "").split("-")[0]  # Extract year from publishedDate
            })


        # Increment the start index for the next page
        start_index += max_results

    # Return the collected data as a DataFrame
    return pd.DataFrame(all_books)

#Fetch data for a specific keyword (e.g., "data science")
books_df21 = fetch_books_data(query="Commerce books ", total_results=200)  # Fetch up to 200 results
books_df21
#Fetch data for a specific keyword (e.g., "data science")
books_df22 = fetch_books_data(query="Accounts books ", total_results=200)  # Fetch up to 200 results
books_df22
#Fetch data for a specific keyword (e.g., "data science")
books_df23 = fetch_books_data(query="Radiology  books ", total_results=200)  # Fetch up to 200 results
books_df23
#Fetch data for a specific keyword (e.g., "data science")
books_df24 = fetch_books_data(query="Science fiction books ", total_results=200)  # Fetch up to 200 results
books_df24
#Fetch data for a specific keyword (e.g., "data science")
books_df25 = fetch_books_data(query="Thriller books ", total_results=200)  # Fetch up to 200 results
books_df25
#Fetch data for a specific keyword (e.g., "data science"),
books_df26 = fetch_books_data(query="Adventure books ", total_results=200)  # Fetch up to 200 results
books_df26
#Fetch data for a specific keyword (e.g., "data science")
books_df27 = fetch_books_data(query="Crime books ", total_results=200)  # Fetch up to 200 results
books_df27
#Fetch data for a specific keyword (e.g., "data science")
books_df28 = fetch_books_data(query="Horror books ", total_results=100)  # Fetch up to 200 results
books_df28
#Fetch data for a specific keyword (e.g., "data science")
books_df29 = fetch_books_data(query="Mystery books ", total_results=100)  # Fetch up to 200 results
books_df29
#Fetch data for a specific keyword (e.g., "data science")
books_df30 = fetch_books_data(query="Historical fiction books ", total_results=100)  # Fetch up to 200 results
books_df30
#Fetch data for a specific keyword (e.g., "data science")
books_df31 = fetch_books_data(query="Security Law books ", total_results=100)  # Fetch up to 200 results
books_df31
#Fetch data for a specific keyword (e.g., "data science")
books_df32= fetch_books_data(query="Finacial Accounting books ", total_results=100)  # Fetch up to 200 results
books_df32
#Fetch data for a specific keyword (e.g., "data science")
books_df33 = fetch_books_data(query="Superhero novels books ", total_results=100)  # Fetch up to 200 results
books_df33
#Fetch data for a specific keyword (e.g., "data science")
books_df34 = fetch_books_data(query="Corporate secretaryship books ", total_results=100)  # Fetch up to 200 results
books_df34
#Fetch data for a specific keyword (e.g., "data science")
books_df35 = fetch_books_data(query="Management Accounting books ", total_results=100)  # Fetch up to 200 results
books_df35
#Fetch data for a specific keyword (e.g., "data science")
books_df36 = fetch_books_data(query="Accounting for Managers books ", total_results=100)  # Fetch up to 200 results
books_df36
#Fetch data for a specific keyword (e.g., "data science")
books_df37 = fetch_books_data(query="Organisation Behaviour books ", total_results=100)  # Fetch up to 200 results
books_df37
#Fetch data for a specific keyword (e.g., "data science")
books_df38 = fetch_books_data(query="Operations Management books ", total_results=100)  # Fetch up to 200 results
books_df38
#Fetch data for a specific keyword (e.g., "data science")
books_df39 = fetch_books_data(query="Sales and Distribution Mangement books ", total_results=100)  # Fetch up to 200 results
books_df39

#Fetch data for a specific keyword (e.g., "data science")
books_df40 = fetch_books_data(query="Hospital Record Mangement books ", total_results=100)  # Fetch up to 200 results
books_df40

fin_df = pd.concat([books_df21,books_df22,books_df23,books_df24,books_df25,books_df26,books_df27,books_df28,books_df29,books_df30,books_df31,books_df32,books_df33,books_df34,books_df35,books_df36,books_df37,books_df38,books_df39,books_df40], ignore_index=True)
fin_df
# Out:
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# Fetching results from 80 to 120...
# Fetching results from 120 to 160...
# Fetching results from 160 to 200...
# Fetching results from 0 to 40...
# Fetching results from 40 to 80...
# ...

# %%
fin_df.isnull().sum()
# Out:
# book_id                        0
# search_key                     0
# book_title                     1
# book_subtitle                  0
# book_authors                   0
# book_description               0
# industryIdentifiers            0
# text_readingModes              0
# image_readingModes             0
# pageCount                     66
# categories                     0
# language                       0
# imageLinks                   219
# ratingsCount                2471
# averageRating               2471
# country                        0
# saleability                    0
# isEbook                        0
# amount_listPrice            1881
# currencyCode_listPrice      1881
# amount_retailPrice          1881
# currencyCode_retailPrice    1881
# buyLink                     1773
# year                           0
# dtype: int64

# %%
fin_df.dropna(inplace=True)
fin_df
# Out:
#            book_id                        search_key  \
# 1     e3UtDAAAQBAJ                   Commerce books
# 3     UPHf6zAGOkgC                   Commerce books
# 12    8N9DEAAAQBAJ                   Commerce books
# 17    y75EEAAAQBAJ                   Commerce books
# 18    Q2n_CgAAQBAJ                   Commerce books
# ...            ...                               ...
# 2889  Iun5CQAAQBAJ  Hospital Record Mangement books
# 2898  cNwvDwAAQBAJ  Hospital Record Mangement books
# 2905  ut2aEAAAQBAJ  Hospital Record Mangement books
# 2912  hgGdEAAAQBAJ  Hospital Record Mangement books
# 2920  eCKKCwAAQBAJ  Hospital Record Mangement books
#
#                                              book_title  \
# 1                         ISC Commerce Class-XI (Vol.I)
# 3                                   The E-Commerce Book
# 12    Chapterwise MCQs Book for Commerce Stream : IS...
# 17    36 Sample Question Papers: CBSE Class 10 for T...
# ...

# %%
lib=pd.concat([final_df,fin_df,fin1_df], ignore_index=True)
lib
# Out:
#           book_id                      search_key  \
# 0    RKvoDwAAQBAJ                    data science
# 1    vcVKAQAAQBAJ                    data science
# 2    axruBQAAQBAJ                    data science
# 3    yPOUDwAAQBAJ                    data science
# 4    XhKSDwAAQBAJ                    data science
# ..            ...                             ...
# 777  pjRkCQAAQBAJ  Artificial Intelligence books
# 778  fEsZ3Ey-Hq4C  Artificial Intelligence books
# 779  XuJoDQAAQBAJ  Artificial Intelligence books
# 780  vbQlDQAAQBAJ  Artificial Intelligence books
# 781  PMHiBAAAQBAJ  Artificial Intelligence books
#
#                                             book_title  \
# 0    Data Science Fundamentals and Practical Approa...
# 1                                   Doing Data Science
# 2                  Data Science and Big Data Analytics
# 3    Business Data Science: Combining Machine Learn...
# 4                            Data Science from Scratch
# ...

# %%
import pandas as pd

data = pd.DataFrame(lib)
print(data)
# Out:
#           book_id                      search_key  \
# 0    RKvoDwAAQBAJ                    data science
# 1    vcVKAQAAQBAJ                    data science
# 2    axruBQAAQBAJ                    data science
# 3    yPOUDwAAQBAJ                    data science
# 4    XhKSDwAAQBAJ                    data science
# ..            ...                             ...
# 777  pjRkCQAAQBAJ  Artificial Intelligence books
# 778  fEsZ3Ey-Hq4C  Artificial Intelligence books
# 779  XuJoDQAAQBAJ  Artificial Intelligence books
# 780  vbQlDQAAQBAJ  Artificial Intelligence books
# 781  PMHiBAAAQBAJ  Artificial Intelligence books
#
#                                             book_title  \
# 0    Data Science Fundamentals and Practical Approa...
# 1                                   Doing Data Science
# 2                  Data Science and Big Data Analytics
# 3    Business Data Science: Combining Machine Learn...
# 4                            Data Science from Scratch
# ...

# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="root"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")
# Out:
# 11

# %%
mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('books',)
# ('ecommerce',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('retailorders',)
# ('sakila',)
# ('student',)
# ('super_stores',)
# ('sys',)
# ('world',)

# %%
import pandas as pd
from sqlalchemy import create_engine,text

# Example DataFrame (replace this with your actual data)
data = pd.DataFrame(lib)

# Replace with your MySQL database credentials
user = "root"
password = "root"
host = "localhost"  # e.g., "localhost" or "127.0.0.1"
database = "books"  # The database to connect to

# Create a SQLAlchemy engine
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{database}")

# Write the DataFrame to the SQL database
data.to_sql('books', con=engine, if_exists='replace', index=False)

# Confirm the operation by querying the table
with engine.connect() as connection:
    result = connection.execute(text("SELECT * FROM books"))
    for row in result:
        print(row)
# Out:
# ('RKvoDwAAQBAJ', 'data science', 'Data Science Fundamentals and Practical Approaches', 'Understand Why Data Science Is the Next', 'Dr. Gypsy Nandi, Dr. Rupam Kumar Sharma', 'Learn how to process and analysis data using PythonÊ KEY FEATURESÊ - The book has theories explained elaborately along with Python code and correspon ... (2507 characters truncated) ... ing for Data Science 6. Time-Series Analysis 7. Deep Learning for Data Science 8. Social Media Analytics 9. Business Analytics 10. Big Data Analytics', '9789389845662, 9389845661', 1, 1, 587.0, 'Computers', 'en', 'http://books.google.com/books/content?id=RKvoDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 1.0, 5.0, 'IN', 'FOR_SALE', 1, 1006.24, 'INR', 503.12, 'INR', 'https://play.google.com/store/books/details?id=RKvoDwAAQBAJ&rdid=book-RKvoDwAAQBAJ&rdot=1&source=gbs_api', '2020')
# ...
